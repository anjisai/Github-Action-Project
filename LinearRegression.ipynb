# %% [markdown]
# <a href="https://colab.research.google.com/github/anjisai/Github-Action-Project/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = {'Hours':[1,2,3,4,5],
        'Marks':[50,60,70,90,100]}
df= pd.DataFrame(data)
print(df)
# Out:
#    Hours  Marks
# 0      1     50
# 1      2     60
# 2      3     70
# 3      4     90
# 4      5    100

# %%
X = df [['Hours']].values
y = df['Marks'].values

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
slope = model.coef_[0]
intercept = model.intercept_
print(f"slope(m): {slope}")
print(f"Intercept(b):{intercept}")
print(f"Equation of the regression line:y={slope:.2f}x+{intercept:.2f}")
# Out:
# slope(m): 12.999999999999998
# Intercept(b):35.00000000000001
# Equation of the regression line:y=13.00x+35.00

# %%
df ['Predicted Marks'] = model.predict(X)
df.head()
# Out:
#    Hours  Marks  Predicted Marks
# 0      1     50             48.0
# 1      2     60             61.0
# 2      3     70             74.0
# 3      4     90             87.0
# 4      5    100            100.0

# %%
plt.scatter(df['Hours'],df['Marks'],color='blue',label='Actual Marks')
plt.plot(df['Hours'],df['Predicted Marks'],color='red',label='Predicted Marks')
